# %% [markdown]
# **Instructions:** replace the string in the second cell, and execute each cell (to execute a cell, hit `Shift+Enter`)

# %%
import numpy as np
# %matplotlib notebook
# or `%matplotlib inline` for non-interactive plots
# or `%matplotlib widget` when using JupyterLab (github.com/matplotlib/jupyter-matplotlib)
import matplotlib.pyplot as plt
from opmd_viewer import OpenPMDTimeSeries
from opmd_viewer import ParticleTracker

# %%
# Replace the string below, to point to your data
ts = OpenPMDTimeSeries('./diags/hdf5/')

# %%
# Interactive GUI
ts.slider()
# Out:
# HBox(children=(Button(description='-', layout=Layout(width='40px'), style=ButtonStyle()), Button(description='…
# HBox(children=(VBox(children=(Accordion(children=(VBox(children=(ToggleButtons(description='Field:', options=(…
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %%
pt = ParticleTracker( ts, iteration=0, species='atoms' )


x_selected, y_selected = ts.get_particle(['x', 'y'], species='atoms', iteration=0, select=pt )
plt.figure(10)
plt.plot(x_selected, y_selected, 'r.')
# Out:
# <img src="data:image/png;base64,..." width="640">
