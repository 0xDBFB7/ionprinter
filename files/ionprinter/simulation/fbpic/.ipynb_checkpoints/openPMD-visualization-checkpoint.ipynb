# %% [markdown]
# **Instructions:** replace the string in the second cell, and execute each cell (to execute a cell, hit `Shift+Enter`)

# %%
import numpy as np
# %matplotlib notebook
# or `%matplotlib inline` for non-interactive plots
# or `%matplotlib widget` when using JupyterLab (github.com/matplotlib/jupyter-matplotlib)
import matplotlib.pyplot as plt
from opmd_viewer import OpenPMDTimeSeries
from opmd_viewer import ParticleTracker

# %%
# Replace the string below, to point to your data
ts = OpenPMDTimeSeries('./diags/hdf5/')

# %%
# Interactive GUI
ts.slider()
# Out:
# HBox(children=(Button(description='-', layout=Layout(width='40px'), style=ButtonStyle()), Button(description='…
# HBox(children=(VBox(children=(Accordion(children=(VBox(children=(ToggleButtons(description='Field:', options=(…
# <img src="data:image/png;base64,..." width="600">
# <img src="data:image/png;base64,..." width="600">

# %%
pt = ParticleTracker( ts, iteration=0, species='atoms' )


x_selected, y_selected = ts.get_particle(['x', 'y'], species='atoms', iteration=0, select=pt )
plt.figure(10)
plt.plot(x_selected, y_selected, 'r.')
# Out:
# ---------------------------------------------------------------------
# OpenPMDException                    Traceback (most recent call last)
# <ipython-input-45-9796037879bd> in <module>
#       2
#       3
# ----> 4 x_selected, y_selected = ts.get_particle(['r', 'y'], species='atoms', iteration=0, select=pt )
#       5 plt.figure(10)
#       6 plt.plot(x_selected, y_selected, 'r.')
#
# ~/anaconda3/lib/python3.6/site-packages/opmd_viewer/openpmd_timeseries/main.py in get_particle(self, var_list, species, t, iteration, select, output, plot, nbins, plot_range, use_field_mesh, histogram_deposition, **kw)
#     232                 "components.\n The available quantities for species '%s' are:"
#     233                 "\n - %s\nPlease set the argument `var_list` "
# --> 234                 "accordingly." % (species, quantity_list) )
#     235
#     236         # Check the format of the particle selection
#
# OpenPMDException: The argument `var_list` is missing or erroneous.
# It should be a list of strings representing species record components.
#  The available quantities for species 'atoms' are:
#  - charge
#  - id
#  - mass
#  - x
#  - y
#  - z
#  - ux
#  - uy
#  - uz
#  - w
# Please set the argument `var_list` accordingly.
